# %%
import pandas as pd

# %%
data = pd.read_csv(r"5. London Housing Data.csv")
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0       1/1/1995  city of london          91449  E09000001         17.0
# 1       2/1/1995  city of london          82203  E09000001          7.0
# 2       3/1/1995  city of london          79121  E09000001         14.0
# 3       4/1/1995  city of london          77101  E09000001          7.0
# 4       5/1/1995  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544   9/1/2019         england         249942  E92000001      64605.0
# 13545  10/1/2019         england         249376  E92000001      68677.0
# 13546  11/1/2019         england         248515  E92000001      67814.0
# 13547  12/1/2019         england         250410  E92000001          NaN
# 13548   1/1/2020         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %% [markdown]
# # Q. 1) Convert the Datatype of 'Date' column to Date-Time format.

# %%
data.head(4)
# Out:
#        date            area  average_price       code  houses_sold  \
# 0  1/1/1995  city of london          91449  E09000001         17.0
# 1  2/1/1995  city of london          82203  E09000001          7.0
# 2  3/1/1995  city of london          79121  E09000001         14.0
# 3  4/1/1995  city of london          77101  E09000001          7.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN

# %%
data.date.unique()
# Out:
# array(['1/1/1995', '2/1/1995', '3/1/1995', '4/1/1995', '5/1/1995',
#        '6/1/1995', '7/1/1995', '8/1/1995', '9/1/1995', '10/1/1995',
#        '11/1/1995', '12/1/1995', '1/1/1996', '2/1/1996', '3/1/1996',
#        '4/1/1996', '5/1/1996', '6/1/1996', '7/1/1996', '8/1/1996',
#        '9/1/1996', '10/1/1996', '11/1/1996', '12/1/1996', '1/1/1997',
#        '2/1/1997', '3/1/1997', '4/1/1997', '5/1/1997', '6/1/1997',
#        '7/1/1997', '8/1/1997', '9/1/1997', '10/1/1997', '11/1/1997',
#        '12/1/1997', '1/1/1998', '2/1/1998', '3/1/1998', '4/1/1998',
#        '5/1/1998', '6/1/1998', '7/1/1998', '8/1/1998', '9/1/1998',
#        '10/1/1998', '11/1/1998', '12/1/1998', '1/1/1999', '2/1/1999',
#        '3/1/1999', '4/1/1999', '5/1/1999', '6/1/1999', '7/1/1999',
#        '8/1/1999', '9/1/1999', '10/1/1999', '11/1/1999', '12/1/1999',
#        '1/1/2000', '2/1/2000', '3/1/2000', '4/1/2000', '5/1/2000',
#        '6/1/2000', '7/1/2000', '8/1/2000', '9/1/2000', '10/1/2000',
# ...

# %%
data.date = pd.to_datetime(data.date)

# %%
data.dtypes
# Out:
# date             datetime64[ns]
# area                     object
# average_price             int64
# code                     object
# houses_sold             float64
# no_of_crimes            float64
# dtype: object

# %% [markdown]
# # Q. 2) Add a new column ''year'' in the dataframe, which contains years only.(B.2) Add a new column ''month'' as 2nd column in the dataframe, which contains month only.

# %%
data["Year"]=data.date.dt.year

# %%
data.insert(1,"month",data.date.dt.month)
data
# Out:
#             date  month            area  average_price       code  \
# 0     1995-01-01      1  city of london          91449  E09000001
# 1     1995-02-01      2  city of london          82203  E09000001
# 2     1995-03-01      3  city of london          79121  E09000001
# 3     1995-04-01      4  city of london          77101  E09000001
# 4     1995-05-01      5  city of london          84409  E09000001
# ...          ...    ...             ...            ...        ...
# 13544 2019-09-01      9         england         249942  E92000001
# 13545 2019-10-01     10         england         249376  E92000001
# 13546 2019-11-01     11         england         248515  E92000001
# 13547 2019-12-01     12         england         250410  E92000001
# 13548 2020-01-01      1         england         247355  E92000001
#
#        houses_sold  no_of_crimes  Year
# 0             17.0           NaN  1995
# 1              7.0           NaN  1995
# 2             14.0           NaN  1995
# ...

# %% [markdown]
# # Q. 3) Remove the columns 'year' and 'month' from the dataframe.

# %%
data.drop(["Year","month"],axis=1,inplace=True)

# %%
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %% [markdown]
# # Q. 4) Show all the records where 'No. of Crimes' is 0. And, how many such records are there ?

# %%
data.head(3)
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN

# %%
data[data.no_of_crimes == 0]
# Out:
#           date            area  average_price       code  houses_sold  \
# 72  2001-01-01  city of london         284262  E09000001         24.0
# 73  2001-02-01  city of london         198137  E09000001         37.0
# 74  2001-03-01  city of london         189033  E09000001         44.0
# 75  2001-04-01  city of london         205494  E09000001         38.0
# 76  2001-05-01  city of london         223459  E09000001         30.0
# ..         ...             ...            ...        ...          ...
# 178 2009-11-01  city of london         397909  E09000001         11.0
# 179 2009-12-01  city of london         411955  E09000001         16.0
# 180 2010-01-01  city of london         464436  E09000001         20.0
# 181 2010-02-01  city of london         490525  E09000001          9.0
# 182 2010-03-01  city of london         498241  E09000001         15.0
#
#      no_of_crimes
# 72            0.0
# 73            0.0
# 74            0.0
# 75            0.0
# 76            0.0
# ...

# %%
len(data[data.no_of_crimes == 0])
# Out:
# 104

# %% [markdown]
# # Q. 5) What is the maximum & minimum 'average_price' per year in england ?

# %%
df1= data[data.area == "england"]

# %%
df1
# Out:
#             date     area  average_price       code  houses_sold  \
# 13248 1995-01-01  england          53203  E92000001      47639.0
# 13249 1995-02-01  england          53096  E92000001      47880.0
# 13250 1995-03-01  england          53201  E92000001      67025.0
# 13251 1995-04-01  england          53591  E92000001      56925.0
# 13252 1995-05-01  england          53678  E92000001      64192.0
# ...          ...      ...            ...        ...          ...
# 13544 2019-09-01  england         249942  E92000001      64605.0
# 13545 2019-10-01  england         249376  E92000001      68677.0
# 13546 2019-11-01  england         248515  E92000001      67814.0
# 13547 2019-12-01  england         250410  E92000001          NaN
# 13548 2020-01-01  england         247355  E92000001          NaN
#
#        no_of_crimes  Year
# 13248           NaN  1995
# 13249           NaN  1995
# 13250           NaN  1995
# 13251           NaN  1995
# 13252           NaN  1995
# ...

# %%
data["Year"]=data.date.dt.year

# %%
df1["average_price"].groupby(data.Year).max()
# Out:
# Year
# 1995     53901
# 1996     55755
# 1997     61564
# 1998     65743
# 1999     75071
# 2000     84191
# 2001     95992
# 2002    119982
# 2003    138985
# 2004    160330
# 2005    167244
# 2006    182031
# 2007    194764
# 2008    191750
# 2009    174136
# 2010    180807
# 2011    177335
# 2012    180129
# 2013    188544
# 2014    203639
# 2015    219582
# 2016    231922
# 2017    242628
# 2018    248620
# 2019    250410
# 2020    247355
# Name: average_price, dtype: int64

# %%
df1["average_price"].groupby(data.Year).min()
# Out:
# Year
# 1995     52788
# 1996     52333
# 1997     55789
# 1998     61659
# 1999     65522
# 2000     75219
# 2001     84245
# 2002     96215
# 2003    121610
# 2004    139719
# 2005    158572
# 2006    166544
# 2007    181824
# 2008    165795
# 2009    159340
# 2010    174458
# 2011    173046
# 2012    174161
# 2013    176816
# 2014    188265
# 2015    202856
# 2016    220361
# 2017    231593
# 2018    240428
# 2019    243281
# 2020    247355
# Name: average_price, dtype: int64

# %% [markdown]
# # Q. 6) What is the Maximum & Minimum No. of Crimes recorded per area ?

# %%
data["no_of_crimes"].groupby(data.area).max().sort_values(ascending=False)
# Out:
# area
# westminster               7461.0
# lambeth                   4701.0
# camden                    4558.0
# southwark                 3821.0
# newham                    3668.0
# hackney                   3466.0
# ealing                    3401.0
# islington                 3384.0
# tower hamlets             3316.0
# croydon                   3263.0
# haringey                  3199.0
# wandsworth                3051.0
# waltham forest            2941.0
# brent                     2937.0
# barnet                    2893.0
# greenwich                 2853.0
# hillingdon                2819.0
# hounslow                  2817.0
# lewisham                  2813.0
# enfield                   2798.0
# kensington and chelsea    2778.0
# hammersmith and fulham    2645.0
# bromley                   2637.0
# redbridge                 2560.0
# barking and dagenham      2049.0
# havering                  1956.0
# bexley                    1914.0
# harrow                    1763.0
# ...

# %%
data["no_of_crimes"].groupby(data.area).min().sort_values(ascending=False)
# Out:
# area
# westminster               3504.0
# lambeth                   2381.0
# southwark                 2267.0
# newham                    2130.0
# camden                    2079.0
# croydon                   2031.0
# islington                 1871.0
# ealing                    1871.0
# hackney                   1870.0
# brent                     1850.0
# barnet                    1703.0
# lewisham                  1675.0
# tower hamlets             1646.0
# enfield                   1635.0
# wandsworth                1582.0
# waltham forest            1575.0
# haringey                  1536.0
# hounslow                  1529.0
# greenwich                 1513.0
# redbridge                 1487.0
# hillingdon                1445.0
# bromley                   1441.0
# kensington and chelsea    1347.0
# hammersmith and fulham    1323.0
# barking and dagenham      1217.0
# havering                  1130.0
# harrow                     937.0
# bexley                     860.0
# ...

# %% [markdown]
# # Q. 7) Show the total count of records of each area, where average price is less than 100000.

# %%
data[data.average_price < 100000]
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13330 2001-11-01         england          95083  E92000001     109149.0
# 13331 2001-12-01         england          95992  E92000001      93329.0
# 13332 2002-01-01         england          96215  E92000001      71678.0
# 13333 2002-02-01         england          96676  E92000001      77131.0
# 13334 2002-03-01         england          98962  E92000001     102828.0
#
#        no_of_crimes  Year
# 0               NaN  1995
# 1               NaN  1995
# ...

# %%
data[data.average_price < 100000].groupby(data.area).sum()
# Out:
#                       average_price  houses_sold  no_of_crimes    Year
# area
# barking and dagenham        5514680      17205.0       22227.0  169834
# barnet                      2328074      11308.0           0.0   49889
# bexley                      4805257      22800.0           0.0  127820
# brent                       3203043      12703.0           0.0   79848
# bromley                     2814808      16617.0           0.0   65865
# city of london               992436        193.0           0.0   21950
# croydon                     4505317      31990.0           0.0  113823
# ealing                      2625621      12432.0           0.0   61871
# east midlands               5616647     719031.0           0.0  191856
# east of england             5357761     769461.0           0.0  151824
# enfield                     4425645      24560.0           0.0  107823
# england                     5957390    7290838.0           0.0  173838
# ...
